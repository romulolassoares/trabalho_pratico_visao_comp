# %%
import os
import json
import pandas as pd
# Diretório dos resultados dos testes
results_directory = "test/results"

reports = []
# Itera sobre cada arquivo no diretório
for foldername in os.listdir(results_directory):
    # Obtém o caminho completo do diretório do teste
    folder_path = os.path.join(results_directory, foldername)
    
    json_file_path = f'{folder_path}/info.json'
    try:
        with open(json_file_path, 'r') as file:
            data = json.load(file)
        # print(data)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
    except FileNotFoundError:
        print(f"File not found: {json_file_path}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        
    # print(data)

    # Verifica se é um diretório
    if os.path.isdir(folder_path):
        
        if os.path.isdir(folder_path) and foldername.startswith("test"):
            print(folder_path,foldername)
            report_df = pd.read_csv(f"{folder_path}/report.csv")
            print(report_df, end='\n\n')
        

print("Script concluído.")
# Out:
# test/results/test2_3_e5b64class10_20231211_220722 test2_3_e5b64class10_20231211_220722
#       Unnamed: 0  precision  recall  f1-score     support
# 0       airplane   0.733628  0.8290  0.778404   1000.0000
# 1     automobile   0.934625  0.7720  0.845564   1000.0000
# 2           bird   0.635417  0.6100  0.622449   1000.0000
# 3            cat   0.588095  0.4940  0.536957   1000.0000
# 4           deer   0.714286  0.7300  0.722057   1000.0000
# 5            dog   0.727385  0.5870  0.649696   1000.0000
# 6           frog   0.654996  0.8980  0.757486   1000.0000
# 7          horse   0.804175  0.8090  0.806580   1000.0000
# 8           ship   0.894025  0.7930  0.840488   1000.0000
# 9          truck   0.778454  0.8960  0.833101   1000.0000
# 10      accuracy   0.741800  0.7418  0.741800      0.7418
# 11     macro avg   0.746509  0.7418  0.739278  10000.0000
# 12  weighted avg   0.746509  0.7418  0.739278  10000.0000
#
# test/results/test4_1_e25b64class10_20231212_004403 test4_1_e25b64class10_20231212_004403
#       Unnamed: 0  precision  recall  f1-score    support
# 0       airplane   0.836557   0.865  0.850541   1000.000
# 1     automobile   0.900000   0.909  0.904478   1000.000
# 2           bird   0.751491   0.756  0.753739   1000.000
# 3            cat   0.644645   0.644  0.644322   1000.000
# 4           deer   0.822245   0.791  0.806320   1000.000
# 5            dog   0.740704   0.737  0.738847   1000.000
# 6           frog   0.861139   0.862  0.861569   1000.000
# 7          horse   0.859281   0.861  0.860140   1000.000
# 8           ship   0.895055   0.887  0.891010   1000.000
# 9          truck   0.868000   0.868  0.868000   1000.000
# 10      accuracy   0.818000   0.818  0.818000      0.818
# 11     macro avg   0.817912   0.818  0.817897  10000.000
# 12  weighted avg   0.817912   0.818  0.817897  10000.000
#
# test/results/test4_2_e25b64class2_20231212_004742 test4_2_e25b64class2_20231212_004742
#      Unnamed: 0  precision    recall  f1-score     support
# 0         Santa   0.858407  0.947883  0.900929  307.000000
# 1     Not Santa   0.941818  0.843648  0.890034  307.000000
# 2      accuracy   0.895765  0.895765  0.895765    0.895765
# 3     macro avg   0.900113  0.895765  0.895482  614.000000
# 4  weighted avg   0.900113  0.895765  0.895482  614.000000
#
# File not found: test/results/OLD/info.json
# test/results/test2_4_e5b64class2_20231211_220758 test2_4_e5b64class2_20231211_220758
#      Unnamed: 0  precision    recall  f1-score     support
# 0         Santa   0.556159  1.000000  0.714785  307.000000
# 1     Not Santa   1.000000  0.201954  0.336043  307.000000
# 2      accuracy   0.600977  0.600977  0.600977    0.600977
# 3     macro avg   0.778080  0.600977  0.525414  614.000000
# 4  weighted avg   0.778080  0.600977  0.525414  614.000000
#
# test/results/test4_3_e25b64class10_20231212_010854 test4_3_e25b64class10_20231212_010854
#       Unnamed: 0  precision  recall  f1-score     support
# 0       airplane   0.836802  0.7640  0.798745   1000.0000
# 1     automobile   0.910124  0.8810  0.895325   1000.0000
# 2           bird   0.700000  0.7560  0.726923   1000.0000
# 3            cat   0.644068  0.5320  0.582694   1000.0000
# 4           deer   0.761815  0.8060  0.783285   1000.0000
# 5            dog   0.651067  0.7930  0.715059   1000.0000
# 6           frog   0.884009  0.7850  0.831568   1000.0000
# 7          horse   0.802357  0.8850  0.841655   1000.0000
# 8           ship   0.935593  0.8280  0.878515   1000.0000
# 9          truck   0.847314  0.8990  0.872392   1000.0000
# 10      accuracy   0.792900  0.7929  0.792900      0.7929
# 11     macro avg   0.797315  0.7929  0.792616  10000.0000
# 12  weighted avg   0.797315  0.7929  0.792616  10000.0000
#
# test/results/test3_3_e25b32class10_20231211_234419 test3_3_e25b32class10_20231211_234419
#       Unnamed: 0  precision  recall  f1-score   support
# 0       airplane   0.871508   0.780  0.823219   1000.00
# 1     automobile   0.936126   0.894  0.914578   1000.00
# 2           bird   0.776923   0.707  0.740314   1000.00
# 3            cat   0.638298   0.690  0.663143   1000.00
# 4           deer   0.822060   0.790  0.805711   1000.00
# 5            dog   0.768053   0.702  0.733542   1000.00
# 6           frog   0.898343   0.813  0.853543   1000.00
# 7          horse   0.841651   0.877  0.858962   1000.00
# 8           ship   0.751001   0.938  0.834149   1000.00
# 9          truck   0.835478   0.909  0.870690   1000.00
# 10      accuracy   0.810000   0.810  0.810000      0.81
# 11     macro avg   0.813944   0.810  0.809785  10000.00
# 12  weighted avg   0.813944   0.810  0.809785  10000.00
#
# test/results/test5_1_e50b128class10_20231212_025758 test5_1_e50b128class10_20231212_025758
#       Unnamed: 0  precision  recall  f1-score     support
# 0       airplane   0.838077  0.8540  0.845963   1000.0000
# 1     automobile   0.902414  0.8970  0.899699   1000.0000
# 2           bird   0.750000  0.7320  0.740891   1000.0000
# 3            cat   0.643821  0.6200  0.631686   1000.0000
# 4           deer   0.776900  0.7870  0.781918   1000.0000
# 5            dog   0.715264  0.7310  0.723046   1000.0000
# 6           frog   0.845709  0.8770  0.861070   1000.0000
# 7          horse   0.867769  0.8400  0.853659   1000.0000
# 8           ship   0.883929  0.8910  0.887450   1000.0000
# 9          truck   0.866000  0.8660  0.866000   1000.0000
# 10      accuracy   0.809500  0.8095  0.809500      0.8095
# 11     macro avg   0.808988  0.8095  0.809138  10000.0000
# 12  weighted avg   0.808988  0.8095  0.809138  10000.0000
#
# test/results/test5_3_e50b128class10_20231212_034108 test5_3_e50b128class10_20231212_034108
#       Unnamed: 0  precision  recall  f1-score     support
# 0       airplane   0.869180  0.7840  0.824395   1000.0000
# 1     automobile   0.919171  0.8870  0.902799   1000.0000
# 2           bird   0.726708  0.7020  0.714140   1000.0000
# 3            cat   0.699625  0.5590  0.621456   1000.0000
# 4           deer   0.647232  0.8770  0.744798   1000.0000
# 5            dog   0.781038  0.6920  0.733828   1000.0000
# 6           frog   0.799078  0.8670  0.831655   1000.0000
# 7          horse   0.785649  0.8650  0.823417   1000.0000
# 8           ship   0.900000  0.8730  0.886294   1000.0000
# 9          truck   0.888774  0.8630  0.875698   1000.0000
# 10      accuracy   0.796900  0.7969  0.796900      0.7969
# 11     macro avg   0.801646  0.7969  0.795848  10000.0000
# 12  weighted avg   0.801646  0.7969  0.795848  10000.0000
#
# test/results/test3_4_e25b32class2_20231211_234707 test3_4_e25b32class2_20231211_234707
#      Unnamed: 0  precision  recall  f1-score  support
# 0         Santa       0.50     1.0  0.666667    307.0
# 1     Not Santa       0.00     0.0  0.000000    307.0
# 2      accuracy       0.50     0.5  0.500000      0.5
# 3     macro avg       0.25     0.5  0.333333    614.0
# 4  weighted avg       0.25     0.5  0.333333    614.0
#
# test/results/test2_1_e5b64class10_20231211_220210 test2_1_e5b64class10_20231211_220210
#       Unnamed: 0  precision  recall  f1-score     support
# 0       airplane   0.750868  0.8650  0.803903   1000.0000
# 1     automobile   0.800681  0.9400  0.864765   1000.0000
# 2           bird   0.688119  0.6950  0.691542   1000.0000
# 3            cat   0.609707  0.6030  0.606335   1000.0000
# 4           deer   0.642857  0.8550  0.733906   1000.0000
# 5            dog   0.778319  0.6390  0.701812   1000.0000
# 6           frog   0.862288  0.8140  0.837449   1000.0000
# 7          horse   0.901515  0.7140  0.796875   1000.0000
# 8           ship   0.867925  0.8740  0.870952   1000.0000
# 9          truck   0.919334  0.7180  0.806289   1000.0000
# 10      accuracy   0.771700  0.7717  0.771700      0.7717
# 11     macro avg   0.782161  0.7717  0.771383  10000.0000
# 12  weighted avg   0.782161  0.7717  0.771383  10000.0000
#
# test/results/test1_4_e5b32class2_20231211_215050 test1_4_e5b32class2_20231211_215050
#      Unnamed: 0  precision    recall  f1-score     support
# 0         Santa   0.825000  0.214984  0.341085  307.000000
# 1     Not Santa   0.548689  0.954397  0.696790  307.000000
# 2      accuracy   0.584691  0.584691  0.584691    0.584691
# 3     macro avg   0.686845  0.584691  0.518937  614.000000
# 4  weighted avg   0.686845  0.584691  0.518937  614.000000
#
# An unexpected error occurred: [Errno 20] Not a directory: 'test/results/test5_.zip/info.json'
# test/results/test1_2_e5b32class2_20231211_214431 test1_2_e5b32class2_20231211_214431
#      Unnamed: 0  precision    recall  f1-score     support
# 0         Santa   0.811209  0.895765  0.851393  307.000000
# 1     Not Santa   0.883636  0.791531  0.835052  307.000000
# 2      accuracy   0.843648  0.843648  0.843648    0.843648
# 3     macro avg   0.847423  0.843648  0.843222  614.000000
# 4  weighted avg   0.847423  0.843648  0.843222  614.000000
#
# test/results/test3_1_e25b32class10_20231211_231229 test3_1_e25b32class10_20231211_231229
#       Unnamed: 0  precision  recall  f1-score     support
# 0       airplane   0.816888  0.8610  0.838364   1000.0000
# 1     automobile   0.898622  0.9130  0.905754   1000.0000
# 2           bird   0.790123  0.7040  0.744580   1000.0000
# 3            cat   0.602444  0.6410  0.621124   1000.0000
# 4           deer   0.818182  0.7560  0.785863   1000.0000
# 5            dog   0.664655  0.7710  0.713889   1000.0000
# 6           frog   0.878625  0.8180  0.847229   1000.0000
# 7          horse   0.866667  0.8450  0.855696   1000.0000
# 8           ship   0.901364  0.8590  0.879672   1000.0000
# 9          truck   0.860465  0.8880  0.874016   1000.0000
# 10      accuracy   0.805600  0.8056  0.805600      0.8056
# 11     macro avg   0.809804  0.8056  0.806619  10000.0000
# 12  weighted avg   0.809804  0.8056  0.806619  10000.0000
#
# test/results/test1_3_e5b32class10_20231211_215013 test1_3_e5b32class10_20231211_215013
#       Unnamed: 0  precision  recall  f1-score     support
# 0       airplane   0.744973  0.8150  0.778415   1000.0000
# 1     automobile   0.928090  0.8260  0.874074   1000.0000
# 2           bird   0.622936  0.6790  0.649761   1000.0000
# 3            cat   0.580715  0.5360  0.557462   1000.0000
# 4           deer   0.760042  0.7190  0.738952   1000.0000
# 5            dog   0.771654  0.5880  0.667423   1000.0000
# 6           frog   0.708502  0.8750  0.782998   1000.0000
# 7          horse   0.868721  0.7610  0.811301   1000.0000
# 8           ship   0.836795  0.8460  0.841372   1000.0000
# 9          truck   0.762148  0.8940  0.822826   1000.0000
# 10      accuracy   0.753900  0.7539  0.753900      0.7539
# 11     macro avg   0.758458  0.7539  0.752458  10000.0000
# 12  weighted avg   0.758458  0.7539  0.752458  10000.0000
#
# test/results/test2_2_e5b64class2_20231211_220303 test2_2_e5b64class2_20231211_220303
#      Unnamed: 0  precision    recall  f1-score     support
# 0         Santa   1.000000  0.055375  0.104938  307.000000
# 1     Not Santa   0.514238  1.000000  0.679204  307.000000
# 2      accuracy   0.527687  0.527687  0.527687    0.527687
# 3     macro avg   0.757119  0.527687  0.392071  614.000000
# 4  weighted avg   0.757119  0.527687  0.392071  614.000000
#
# test/results/test3_2_e25b32class2_20231211_231613 test3_2_e25b32class2_20231211_231613
#      Unnamed: 0  precision    recall  f1-score     support
# 0         Santa   0.913043  0.957655  0.934817  307.000000
# 1     Not Santa   0.955479  0.908795  0.931553  307.000000
# 2      accuracy   0.933225  0.933225  0.933225    0.933225
# 3     macro avg   0.934261  0.933225  0.933185  614.000000
# 4  weighted avg   0.934261  0.933225  0.933185  614.000000
#
# test/results/test1_1_e5b32class10_20231211_214334 test1_1_e5b32class10_20231211_214334
#       Unnamed: 0  precision  recall  f1-score     support
# 0       airplane   0.855866  0.7660  0.808443   1000.0000
# 1     automobile   0.947368  0.8100  0.873315   1000.0000
# 2           bird   0.663826  0.7010  0.681907   1000.0000
# 3            cat   0.593269  0.6170  0.604902   1000.0000
# 4           deer   0.754386  0.7310  0.742509   1000.0000
# 5            dog   0.732955  0.6450  0.686170   1000.0000
# 6           frog   0.748722  0.8790  0.808648   1000.0000
# 7          horse   0.772251  0.8850  0.824790   1000.0000
# 8           ship   0.896951  0.8530  0.874423   1000.0000
# 9          truck   0.831721  0.8600  0.845624   1000.0000
# 10      accuracy   0.774700  0.7747  0.774700      0.7747
# 11     macro avg   0.779732  0.7747  0.775073  10000.0000
# 12  weighted avg   0.779732  0.7747  0.775073  10000.0000
#
# test/results/test5_4_e50b128class2_20231212_034613 test5_4_e50b128class2_20231212_034613
#      Unnamed: 0  precision    recall  f1-score     support
# 0         Santa   0.918495  0.954397  0.936102  307.000000
# 1     Not Santa   0.952542  0.915309  0.933555  307.000000
# 2      accuracy   0.934853  0.934853  0.934853    0.934853
# 3     macro avg   0.935519  0.934853  0.934829  614.000000
# 4  weighted avg   0.935519  0.934853  0.934829  614.000000
#
# test/results/test4_4_e25b64class2_20231212_011137 test4_4_e25b64class2_20231212_011137
#      Unnamed: 0  precision    recall  f1-score     support
# 0         Santa   0.844985  0.905537  0.874214  307.000000
# 1     Not Santa   0.898246  0.833876  0.864865  307.000000
# 2      accuracy   0.869707  0.869707  0.869707    0.869707
# 3     macro avg   0.871615  0.869707  0.869539  614.000000
# 4  weighted avg   0.871615  0.869707  0.869539  614.000000
#
# test/results/test5_2_e50b128class2_20231212_030449 test5_2_e50b128class2_20231212_030449
#      Unnamed: 0  precision    recall  f1-score     support
# 0         Santa   0.979866  0.951140  0.965289  307.000000
# 1     Not Santa   0.952532  0.980456  0.966292  307.000000
# 2      accuracy   0.965798  0.965798  0.965798    0.965798
# 3     macro avg   0.966199  0.965798  0.965791  614.000000
# 4  weighted avg   0.966199  0.965798  0.965791  614.000000
#
# Script concluído.

# %%
for e in reports:
# Out:
#   Cell In[2], line 2
#
#     ^
# SyntaxError: incomplete input
